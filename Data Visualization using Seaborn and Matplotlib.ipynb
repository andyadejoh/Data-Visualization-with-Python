# %% [markdown]
# # Reading and writing to CSV

# %%
import pandas as pd

# %% [markdown]
# # Read

# %%
#reading a csv file and assigning a name to the dataframe
df = pd.read_csv('melb_data.csv')
df.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# 0        NaN        Yarra  -37.7996    144.9984  Northern Metropolitan
# 1     1900.0        Yarra  -37.8079    144.9934  Northern Metropolitan
# 2     1900.0        Yarra  -37.8093    144.9944  Northern Metropolitan
# 3        NaN        Yarra  -37.7969    144.9969  Northern Metropolitan
# 4     2014.0        Yarra  -37.8072    144.9941  Northern Metropolitan
#
#   Propertycount
# 0        4019.0
# 1        4019.0
# 2        4019.0
# 3        4019.0
# 4        4019.0
#
# [5 rows x 21 columns]

# %%
#Writing to CSV 
df.to_csv('melb2_data.csv')

# %%
print('HELLO WORLD')
# Out:
# HELLO WORLD

# %% [markdown]
# # Scatterplot, Bar, Pie and Subplots

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

plt.plot(xpoints, ypoints)
plt.show()

# %%
y = np.array([2,4,6,8,10])
plt.plot(y, 'o-b')

plt.show()

# %%
x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])
x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 7, 11])

plt.plot(x1, y1, x2, y2)
# Out:
# [<matplotlib.lines.Line2D at 0x7fa20d738070>,
#  <matplotlib.lines.Line2D at 0x7fa20d7380a0>]

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("Sports Watch Data", fontdict = font1)
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)

plt.plot(x, y)
plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)

plt.show()

# %%
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.plot(x,y)

plt.show()

# %% [markdown]
# # SUBPLOTS

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 1, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 1, 2)
plt.plot(x,y)

plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y)
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)

#day two, the age and speed of 15 cars:
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y)

plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')

plt.show()

# %% [markdown]
# # Barplots

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y)
plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x, y)
plt.show()

# %%
x = np.random.normal(170, 10, 250)

plt.hist(x)
plt.show()

# %%
y = np.array([35, 25, 25, 15])

plt.pie(y)
plt.show()

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.show()

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.2,0,0,0]

plt.pie(y, explode = myexplode, shadow = True, labels = mylabels)
plt.legend(title = "Four Fruits:")
plt.show()

# %% [markdown]
# # SVM

# %%
original_data = pd.read_csv('https://raw.githubusercontent.com/prvnktech/003-Support-Vector-Machine-SVM-Example/main/applicant.csv', names=[
        "Age","Workclass","fnlwgt","Education","Education-Num","Marital Status",
        "Occupation","Relationship","Race","Gender","Capital Gain","Capital Loss",
        "Hours per week","Country","Target"],
    sep=r'\s*,\s*',
    engine='python',
    na_values='?')

# %%
original_data.head()
# Out:
#    Age         Workclass  fnlwgt  Education  Education-Num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        Marital Status         Occupation   Relationship   Race  Gender  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    Capital Gain  Capital Loss  Hours per week        Country Target
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40  United-States  <=50K
# 4             0             0              40           Cuba  <=50K

# %%
original_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32561 non-null  int64
#  1   Workclass       30725 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   Education       32561 non-null  object
#  4   Education-Num   32561 non-null  int64
#  5   Marital Status  32561 non-null  object
#  6   Occupation      30718 non-null  object
#  7   Relationship    32561 non-null  object
#  8   Race            32561 non-null  object
#  9   Gender          32561 non-null  object
#  10  Capital Gain    32561 non-null  int64
#  11  Capital Loss    32561 non-null  int64
#  12  Hours per week  32561 non-null  int64
#  13  Country         31978 non-null  object
#  14  Target          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
categoricals = [col for col in original_data.columns if original_data[col].dtype == 'object']
categoricals
# Out:
# ['Workclass',
#  'Education',
#  'Marital Status',
#  'Occupation',
#  'Relationship',
#  'Race',
#  'Gender',
#  'Country',
#  'Target']

# %%
for col in categoricals:
    print(original_data[col].nunique())
# Out:
# 8
# 16
# 7
# 14
# 6
# 5
# 2
# 41
# 2

# %% [markdown]
# # Zummit version of Visualization

# %%
import matplotlib.pyplot as plt
import math
get_ipython().run_line_magic('matplotlib', 'inline')

fig = plt.figure(figsize=(20,20))
cols=3
rows=math.ceil(float(original_data.shape[1])/cols)

for i,column in enumerate(['Age','Workclass','Education','Occupation','Race','Gender']):
    ax=fig.add_subplot(rows,cols,i+1)
    ax.set_title(column)
    if original_data.dtypes[column] ==np.object: 
        original_data[column].value_counts().plot(kind="bar",axes=ax)
    else:
        original_data[column].hist(axes=ax)
        plt.xticks(rotation='vertical')
plt.subplots_adjust(hspace=0.7, wspace=0.2)
plt.show()

# %%
original_data.shape
# Out:
# (32561, 15)

# %% [markdown]
# # My Version of Visualization

# %%
b = 1
plt.figure(figsize=(20,10))
for i in ['Age','Workclass','Education','Occupation','Race','Gender']:
    plt.subplot(2,3,b)
    if original_data[i].dtype == 'object':
        original_data[i].value_counts().plot(kind = "bar")
    else:
        plt.hist(original_data[i])
        plt.grid()
    plt.title(i)    
    b = b+1 
    
    
plt.subplots_adjust(hspace=0.7, wspace=0.2)
plt.show()

# %%
original_data.head()
# Out:
#    Age         Workclass  fnlwgt  Education  Education-Num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        Marital Status         Occupation   Relationship   Race  Gender  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    Capital Gain  Capital Loss  Hours per week        Country Target
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40  United-States  <=50K
# 4             0             0              40           Cuba  <=50K

# %%
import sklearn.preprocessing as preprocessing
le=preprocessing.LabelEncoder()
original_data['Occupation']=le.fit_transform(original_data['Occupation'].astype(str))
original_data.head()
# Out:
#    Age         Workclass  fnlwgt  Education  Education-Num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        Marital Status  Occupation   Relationship   Race  Gender  Capital Gain  \
# 0       Never-married           0  Not-in-family  White    Male          2174
# 1  Married-civ-spouse           3        Husband  White    Male             0
# 2            Divorced           5  Not-in-family  White    Male             0
# 3  Married-civ-spouse           5        Husband  Black    Male             0
# 4  Married-civ-spouse           9           Wife  Black  Female             0
#
#    Capital Loss  Hours per week        Country Target
# 0             0              40  United-States  <=50K
# 1             0              13  United-States  <=50K
# 2             0              40  United-States  <=50K
# 3             0              40  United-States  <=50K
# 4             0              40           Cuba  <=50K

# %%
original_data['Target']=le.fit_transform(original_data['Target'].astype(str))
original_data.tail()
# Out:
#        Age     Workclass  fnlwgt   Education  Education-Num  \
# 32556   27       Private  257302  Assoc-acdm             12
# 32557   40       Private  154374     HS-grad              9
# 32558   58       Private  151910     HS-grad              9
# 32559   22       Private  201490     HS-grad              9
# 32560   52  Self-emp-inc  287927     HS-grad              9
#
#            Marital Status  Occupation Relationship   Race  Gender  \
# 32556  Married-civ-spouse          12         Wife  White  Female
# 32557  Married-civ-spouse           6      Husband  White    Male
# 32558             Widowed           0    Unmarried  White  Female
# 32559       Never-married           0    Own-child  White    Male
# 32560  Married-civ-spouse           3         Wife  White  Female
#
#        Capital Gain  Capital Loss  Hours per week        Country  Target
# 32556             0             0              38  United-States       0
# 32557             0             0              40  United-States       1
# 32558             0             0              40  United-States       0
# 32559             0             0              20  United-States       0
# 32560         15024             0              40  United-States       1

# %%
original_data.groupby('Education-Num').Target.mean().plot(kind='bar')
plt.show()

# %%
from sklearn.model_selection import train_test_split
X=original_data[['Education-Num','Occupation']]
Y=original_data['Target']

# %%
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 32556    0
# 32557    1
# 32558    0
# 32559    0
# 32560    1
# Name: Target, Length: 32561, dtype: int64

# %%
X_train,x_test,Y_train,y_test=train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
from sklearn.svm import SVC
classifier=SVC()
classifier.fit(X_train,Y_train)
score=classifier.score(x_test,y_test)
print(score)
# Out:
# 0.7861200675571933

# %%
import seaborn as sns
corrmat=original_data.corr()

corrmat
# Out:
#                      Age    fnlwgt  Education-Num  Occupation  Capital Gain  \
# Age             1.000000 -0.076646       0.036527    0.012626      0.077674
# fnlwgt         -0.076646  1.000000      -0.043195   -0.000521      0.000432
# Education-Num   0.036527 -0.043195       1.000000    0.044096      0.122630
# Occupation      0.012626 -0.000521       0.044096    1.000000      0.012350
# Capital Gain    0.077674  0.000432       0.122630    0.012350      1.000000
# Capital Loss    0.057775 -0.010252       0.079923    0.004540     -0.031615
# Hours per week  0.068756 -0.018768       0.148123   -0.056995      0.078409
# Target          0.234037 -0.009463       0.335154    0.010802      0.223329
#
#                 Capital Loss  Hours per week    Target
# Age                 0.057775        0.068756  0.234037
# fnlwgt             -0.010252       -0.018768 -0.009463
# Education-Num       0.079923        0.148123  0.335154
# Occupation          0.004540       -0.056995  0.010802
# Capital Gain       -0.031615        0.078409  0.223329
# Capital Loss        1.000000        0.054256  0.150526
# Hours per week      0.054256        1.000000  0.229689
# Target              0.150526        0.229689  1.000000

# %%
f,ax=plt.subplots(figsize=(7,7))
sns.heatmap(corrmat,vmax=.8, square=True, annot = True);
plt.show()

# %%
original_data['Race']=le.fit_transform(original_data['Race'].astype(str))
original_data['Gender']=le.fit_transform(original_data['Gender'].astype(str))
original_data['Marital Status']=le.fit_transform(original_data['Marital Status'].astype(str))
original_data['Education']=le.fit_transform(original_data['Education'].astype(str))
corrmat=original_data.corr()

corrmat
# Out:
#                      Age    fnlwgt  Education  Education-Num  Marital Status  \
# Age             1.000000 -0.076646  -0.036962       0.036527       -0.266288
# fnlwgt         -0.076646  1.000000  -0.014769      -0.043195        0.028153
# Education      -0.036962 -0.014769   1.000000       0.240726       -0.011691
# Education-Num   0.036527 -0.043195   0.240726       1.000000       -0.069304
# Marital Status -0.266288  0.028153  -0.011691      -0.069304        1.000000
# Occupation      0.012626 -0.000521  -0.038237       0.044096        0.052847
# Race            0.028718 -0.021291   0.002959       0.031838       -0.068013
# Gender          0.088832  0.026858  -0.029312       0.012280       -0.129314
# Capital Gain    0.077674  0.000432   0.021131       0.122630       -0.043393
# Capital Loss    0.057775 -0.010252   0.006176       0.079923       -0.034187
# Hours per week  0.068756 -0.018768   0.022506       0.148123       -0.190519
# Target          0.234037 -0.009463   0.041866       0.335154       -0.199307
#
#                 Occupation      Race    Gender  Capital Gain  Capital Loss  \
# Age               0.012626  0.028718  0.088832      0.077674      0.057775
# fnlwgt           -0.000521 -0.021291  0.026858      0.000432     -0.010252
# Education        -0.038237  0.002959 -0.029312      0.021131      0.006176
# Education-Num     0.044096  0.031838  0.012280      0.122630      0.079923
# Marital Status    0.052847 -0.068013 -0.129314     -0.043393     -0.034187
# Occupation        1.000000 -0.009966  0.026116      0.012350      0.004540
# Race             -0.009966  1.000000  0.087204      0.011145      0.018899
# Gender            0.026116  0.087204  1.000000      0.048480      0.045567
# Capital Gain      0.012350  0.011145  0.048480      1.000000     -0.031615
# Capital Loss      0.004540  0.018899  0.045567     -0.031615      1.000000
# Hours per week   -0.056995  0.041910  0.229309      0.078409      0.054256
# Target            0.010802  0.071846  0.215980      0.223329      0.150526
#
#                 Hours per week    Target
# Age                   0.068756  0.234037
# fnlwgt               -0.018768 -0.009463
# Education             0.022506  0.041866
# Education-Num         0.148123  0.335154
# Marital Status       -0.190519 -0.199307
# Occupation           -0.056995  0.010802
# Race                  0.041910  0.071846
# Gender                0.229309  0.215980
# Capital Gain          0.078409  0.223329
# Capital Loss          0.054256  0.150526
# Hours per week        1.000000  0.229689
# Target                0.229689  1.000000

# %%
f,ax=plt.subplots(figsize=(10,10))
sns.heatmap(corrmat,vmax=.8, square=True, annot = True);
plt.show()

# %%
f,ax=plt.subplots(figsize=(7,7))
sns.heatmap(corrmat,vmax=.8,square=True,annot=True,fmt='.2f')
plt.show()

# %%
X=original_data[['Education-Num','Occupation','Age','Gender']]
Y=original_data['Target']
X_train,x_test,Y_train,y_test=train_test_split(X,Y,test_size=0.2,random_state=0)
classifier=SVC()
classifier.fit(X_train,Y_train)
score=classifier.score(x_test,y_test)
print(score)
# Out:
# 0.7953324120988792

# %%
car = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}

x = car.keys()

print(car["brand"])
# Out:
# Ford

# %%
data = pd.read_csv('sample_submission.csv')
data
# Out:
#          id  cuisine
# 0     35203  italian
# 1     17600  italian
# 2     35200  italian
# 3     17602  italian
# 4     17605  italian
# ...     ...      ...
# 9939  46537  italian
# 9940  30854  italian
# 9941  15430  italian
# 9942  46530  italian
# 9943  30849  italian
#
# [9944 rows x 2 columns]

# %%
data.groupby(['cuisine'])['id'].nunique()
# Out:
# cuisine
# italian    9944
# Name: id, dtype: int64

# %% [markdown]
# # DEEP LEARNING
